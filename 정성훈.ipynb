# %%
import pandas as pd
# Out:
# C:\Users\gnsl1\AppData\Local\Temp\ipykernel_18056\4080736814.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df = pd.read_csv('project_groupB_data.csv')
df
# Out:
#                                   user_id first_name     last_name  \
# 0    bb0aa56d-fd4e-461a-871f-6f4fd9c4d1b9      Conny  Jerzykiewicz
# 1    59740d2b-5fca-4107-a4a8-c77c2aaa7b7e   Engracia      Radbourn
# 2    0e07978a-443f-418a-88a8-08d111d2b8b9     Cassie        Jockle
# 3    57a9003b-f041-4643-80e6-bafcc2ad35dc   Papagena          Oles
# 4    806ecf02-f399-41ac-ba5d-f97c6caefc07      Boyce   Fleischmann
# ..                                    ...        ...           ...
# 995  de5d3a50-d19a-4209-ad31-736e8cc8f618  Reginauld      Maxwaile
# 996  68ae27bc-1b54-465e-985f-af0143290ed8       Elia        Gatley
# 997  ae699faf-4c6d-4f81-a212-fc1f2324ad8b     Gabbey         Egdal
# 998  eacd032b-0752-4f72-b45d-643452c788d5        Ash        Bedome
# 999  6ac0b488-ac47-4048-8fb8-07b2cfa98440     Walden         Rigby
#
#                               email gender       ip_address    country  \
# 0    cjerzykiewicz0@sourceforge.net      F   178.160.146.88   Mongolia
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   user_id            1000 non-null   object
#  1   first_name         1000 non-null   object
#  2   last_name          1000 non-null   object
#  3   email              1000 non-null   object
#  4   gender             1000 non-null   object
#  5   ip_address         1000 non-null   object
#  6   country            1000 non-null   object
#  7   pay_store          1000 non-null   object
#  8   pay_amount         1000 non-null   int64
#  9   information_agree  1000 non-null   bool
#  10  first_login_date   1000 non-null   object
#  11  pay_user_type      1000 non-null   object
#  12  level              1000 non-null   int64
#  13  action_user_type   1000 non-null   object
#  14  playtime           1000 non-null   float64
#  15  battle_pass_level  849 non-null    float64
# ...

# %%
df.describe()
# Out:
#           pay_amount        level     playtime  battle_pass_level
# count    1000.000000  1000.000000  1000.000000         849.000000
# mean   506928.942000    50.067000  5297.402230          10.577150
# std    283274.383373    28.874977  2826.981267           5.819129
# min      2506.000000     1.000000    11.040000           0.000000
# 25%    264367.500000    25.750000  2981.510000           6.000000
# 50%    516729.000000    49.000000  5377.085000          11.000000
# 75%    732825.000000    75.000000  7683.482500          15.000000
# max    999808.000000   100.000000  9996.170000          20.000000

# %%
df.isna().sum()
# Out:
# user_id                0
# first_name             0
# last_name              0
# email                  0
# gender                 0
# ip_address             0
# country                0
# pay_store              0
# pay_amount             0
# information_agree      0
# first_login_date       0
# pay_user_type          0
# level                  0
# action_user_type       0
# playtime               0
# battle_pass_level    151
# dtype: int64

# %%
df['battle_pass_level'].unique()
# Out:
# array([ 7.,  2., 18.,  3.,  0.,  6., 15., 20.,  9., nan, 14., 19.,  4.,
#        17.,  8.,  5., 13., 10.,  1., 12., 16., 11.])

# %%
df.count()
# Out:
# user_id              1000
# first_name           1000
# last_name            1000
# email                1000
# gender               1000
# ip_address           1000
# country              1000
# pay_store            1000
# pay_amount           1000
# information_agree    1000
# first_login_date     1000
# pay_user_type        1000
# level                1000
# action_user_type     1000
# playtime             1000
# battle_pass_level     849
# dtype: int64

# %%
battle_pass_nan = df[df['battle_pass_level'].isna()]
battle_pass_nan.head(6)
# Out:
#                                  user_id first_name last_name  \
# 23  a4571369-dfb3-4427-8b25-8c04e12bfb6a   Charlton  Monteith
# 28  f00169b6-d47b-47cf-94ac-f02383d473cd      Susie   Allnatt
# 30  19ad0a34-f1f9-4fa1-847b-82eef91944e5       Jack  Chastney
# 49  ceef6ea6-688c-4704-bc0b-99bbd82a07b5     Pavlov    Hintze
# 58  26897887-85f3-4ab1-9084-af35cb30ea59   Virginie    Lusher
# 59  6f445a6d-d724-4fbb-8235-b3ba5af07da0   Bancroft   Trodler
#
#                           email gender       ip_address    country pay_store  \
# 23  cmonteithn@seattletimes.com      F  229.211.115.195     Mexico     Other
# 28          sallnatts@skype.com      M    46.18.148.230     Brazil     Other
# 30     jchastneyu@google.com.br      M  101.169.101.199  Macedonia       IOS
# 49         phintze1d@zimbio.com      F    190.33.10.109      Syria     Other
# 58       vlusher1m@amazon.co.jp      F   32.133.249.158   Ethiopia     Other
# ...

# %%
payAmountZero = df[df['pay_amount']==0]
payAmountZero
# Out:
# Empty DataFrame
# Columns: [user_id, first_name, last_name, email, gender, ip_address, country, pay_store, pay_amount, information_agree, first_login_date, pay_user_type, level, action_user_type, playtime, battle_pass_level]
# Index: []

# %%
df['action_user_type'].unique()
# Out:
# array(['pve', 'pvp', 'fishing', 'raid'], dtype=object)

# %%
import seaborn as sns

tmp = sns.pairplot(df, hue='pay_user_type')
tmp
